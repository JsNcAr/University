# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.optimize import curve_fit
import sys

sys.path.append('/home/UANDES/jn.arias/Programing/Herramientas')

import MinimosCuadradosOrdinarios as mc
import MetodosBasicos as mb

# %%
import Datos as dt

# %%
E11, E12, E13, E14, E15 = dt.E11, dt.E12, dt.E13, dt.E14, dt.E15
I4, I5 = dt.I4, dt.I5

# %%
def graf (x, y, i):
    plt.scatter(x,y)
    plt.title('Distancia VS Minimo')
    plt.xlabel('Minimo')
    plt.ylabel('Distancia')
    
    B = mc.MinCua(x,y)
    b= B[0] 
    m=B[1] 
    x=B[2] 
    y=B[4] 
    plt.plot([min(x), max(x)], [m*min(x) + b, m*max(x) + b], c = "orange")
    
    plt.show()
    plt.savefig(i)

# %%
graf(I4, E11, '1.png')
graf(I4, E12, '2.png')
graf(I4, E13, '3.png')
graf(I4, E14, '4.png')
graf(I5, E15, '5.png')
