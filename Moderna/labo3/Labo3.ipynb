# %%
import numpy as np
import matplotlib.pyplot as plt

import sys

sys.path.append('/home/ramsus/Programming/NicolasPersonal/University/Herramientas')

import MinimosCuadradosOrdinarios as mc
import MetodosBasicos as mb

# %%
import Datos as dt

# %%
dis, c = dt.distancia, dt.centro
H, Hg, Ne, Kr = dt.H, dt.Hg, dt.Ne, dt.Kr
Hl, Hgl, Nel, Krl = dt.Hl, dt.Hgl, dt.Nel, dt.Krl

# %%
plt.scatter(1/H, Hl)
mb.ajuCua(1/H, Hl, 'red', 'hidrogeno' )

plt.scatter(1/Hg, Hgl)
mb.ajuCua(1/Hg, Hgl, 'blue', 'mercurio' )

plt.scatter(1/Ne, Nel)
mb.ajuCua(1/Ne, Nel, 'green', 'Neon' )

plt.scatter(1/Kr, Krl)
mb.ajuCua(1/Kr, Krl, 'orange', 'Cripton' )

plt.legend()
plt.figtext(0,0,'Ajuste Hidrogeno: 5.93e-01x² -2.11e+01x + 6.52e+02 ')
plt.figtext(0,-0.05,'Ajuste Mercurio: -6.54e-01x² 4.74e+01x + -2.68e+02 ')
plt.figtext(0,-0.1,'Ajuste Neon: -2.97e+00x² 2.12e+02x + -3.17e+03')
plt.figtext(0,-0.15,'Ajuste Cripton: -7.50e-01x² 6.28e+01x + -6.49e+02 ')
plt.show()

# %%
x = 1/np.linspace(3,5, num = 3)**2
y = 1000000000/Hl
B = mc.MinCua(x,y )
m = B[1]
b= B[0]

plt.plot([min(x), max(x)] , [m*min(x) + b, m*max(x) + b], c = "orange" )
plt.scatter(x, y)

print(str(B[1]) + 'x' + str(B[0]) )
# Out:
# 7331382.883910894x1251889.5005402672

# %%
Ph = mb.ajuCuaEcu(H, Hl)
Phg = mb.ajuCuaEcu(Hg, Hgl)
Pne = mb.ajuCuaEcu(Ne, Nel)
Pkr = mb.ajuCuaEcu(Kr, Krl)

ph0, ph1, ph2 = '{:.2e}'.format(Ph[0]), '{:.2e}'.format(Ph[1]), '{:.2e}'.format(Ph[2])
phg0, phg1, phg2 = '{:.2e}'.format(Phg[0]), '{:.2e}'.format(Phg[1]), '{:.2e}'.format(Phg[2])
pne0, pne1, pne2 = '{:.2e}'.format(Pne[0]), '{:.2e}'.format(Pne[1]), '{:.2e}'.format(Pne[2])
pkr0, pkr1, pkr2 = '{:.2e}'.format(Pkr[0]), '{:.2e}'.format(Pkr[1]), '{:.2e}'.format(Pkr[2])

print('Ajuste Hidrogeno: ' + ph0+ 'x² '+ ph1+ 'x + '+ ph2)
print('Ajuste Mercurio: ' + phg0+ 'x² '+ phg1+ 'x + '+ phg2)
print('Ajuste Neon: ' + pne0+ 'x² '+ pne1+ 'x + '+ pne2)
print('Ajuste Cripton: ' + pkr0+ 'x² '+ pkr1+ 'x + '+ pkr2)
# Out:
# Ajuste Hidrogeno: 5.93e-01x² -2.11e+01x + 6.52e+02
# Ajuste Mercurio: -6.54e-01x² 4.74e+01x + -2.68e+02
# Ajuste Neon: -2.97e+00x² 2.12e+02x + -3.17e+03
# Ajuste Cripton: -7.50e-01x² 6.28e+01x + -6.49e+02
